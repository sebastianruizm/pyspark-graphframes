# %% [markdown]
# ## Demo GraphFrames con PySpark
#
#
#
# Autor: [Sebastian Ruiz Martinez](https://www.linkedin.com/in/sebastianruizmartinez/)

# %% [markdown]
# ### Dataset
#
# Referencia: [SF Bay Area Bike Share](https://www.kaggle.com/benhamner/sf-bay-area-bike-share)

# %%
path = '/databricks-datasets/definitive-guide/data/bike-data/201508_trip_data.csv'

df_trips = spark.read.csv(path, header=True)

df_trips = df_trips.select(
  'Trip ID', 
  'Start Station', 
  'Start Terminal', 
  'End Station', 
  'End Terminal'
)

df_trips.createOrReplaceTempView('trips')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# %sql
SELECT * FROM trips LIMIT 5
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>Trip ID</th><th>Start Station</th><th>Start Terminal</th><th>End Station</th><th>End Terminal</th></tr></thead><tbody><tr><td>913460</td><td>Harry Bridges Plaza (Ferry Building)</td><td>50</td><td>San Francisco Caltrain (Townsend at 4th)</td><td>70</td></tr><tr><td>913459</td><td>San Antonio Shopping Center</td><td>31</td><td>Mountain View City Hall</td><td>27</td></tr><tr><td>913455</td><td>Post at Kearny</td><td>47</td><td>2nd at South Park</td><td>64</td></tr><tr><td>913454</td><td>San Jose City Hall</td><td>10</td><td>San Salvador at 1st</td><td>8</td></tr><tr><td>913453</td><td>Embarcadero at Folsom</td><td>51</td><td>Embarcadero at Sansome</td><td>60</td></tr></tbody></table></div>

# %% [markdown]
# ### Edges

# %%
edges = df_trips.selectExpr(
  '`Start Terminal` AS src', 
  '`End Terminal` AS dst', 
  '`Trip ID` AS tripid'
)

display(edges.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>src</th><th>dst</th><th>tripid</th></tr></thead><tbody><tr><td>50</td><td>70</td><td>913460</td></tr><tr><td>31</td><td>27</td><td>913459</td></tr><tr><td>47</td><td>64</td><td>913455</td></tr><tr><td>10</td><td>8</td><td>913454</td></tr><tr><td>51</td><td>60</td><td>913453</td></tr></tbody></table></div>

# %% [markdown]
# ### Vertices

# %%
df_start_terminal = df_trips.selectExpr('`Start Terminal` AS id', '`Start Station` AS desc_terminal').distinct()
df_end_terminal = df_trips.selectExpr('`End Terminal` AS id', '`End Station` AS desc_terminal').distinct()

vertices = df_start_terminal.union(df_end_terminal).distinct()

display(vertices.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>desc_terminal</th></tr></thead><tbody><tr><td>31</td><td>San Antonio Shopping Center</td></tr><tr><td>71</td><td>Powell at Post (Union Square)</td></tr><tr><td>10</td><td>San Jose City Hall</td></tr><tr><td>41</td><td>Clay at Battery</td></tr><tr><td>22</td><td>Redwood City Caltrain Station</td></tr></tbody></table></div>

# %% [markdown]
# ### GraphFrames

# %%
from graphframes import *

g = GraphFrame(vertices, edges)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(g.vertices.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>desc_terminal</th></tr></thead><tbody><tr><td>31</td><td>San Antonio Shopping Center</td></tr><tr><td>71</td><td>Powell at Post (Union Square)</td></tr><tr><td>10</td><td>San Jose City Hall</td></tr><tr><td>41</td><td>Clay at Battery</td></tr><tr><td>22</td><td>Redwood City Caltrain Station</td></tr></tbody></table></div>

# %%
display(g.edges.limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>src</th><th>dst</th><th>tripid</th></tr></thead><tbody><tr><td>50</td><td>70</td><td>913460</td></tr><tr><td>31</td><td>27</td><td>913459</td></tr><tr><td>47</td><td>64</td><td>913455</td></tr><tr><td>10</td><td>8</td><td>913454</td></tr><tr><td>51</td><td>60</td><td>913453</td></tr></tbody></table></div>

# %% [markdown]
# ### Degrees

# %% [markdown]
# <img border="0" alt="Degrees" src="https://upload.wikimedia.org/wikipedia/commons/thumb/7/77/DirectedDegrees.svg/390px-DirectedDegrees.svg.png" width="400" height="300">
#
# (inDegrees, outDegrees)

# %% [markdown]
# ### inDegrees
# Numero de edges que ingresan a un vertex

# %%
# %sql
SELECT count(*) FROM trips WHERE `End Terminal` = '70'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>34810</td></tr></tbody></table></div>

# %%
display(g.inDegrees.filter("id = 70"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>inDegree</th></tr></thead><tbody><tr><td>70</td><td>34810</td></tr></tbody></table></div>

# %% [markdown]
# ### outDegrees
# Numero de edges que salen de un vertex

# %%
# %sql
SELECT count(*) FROM trips WHERE `Start Terminal` = '70'
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>count(1)</th></tr></thead><tbody><tr><td>26304</td></tr></tbody></table></div>

# %%
display(g.outDegrees.filter("id = 70"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>outDegree</th></tr></thead><tbody><tr><td>70</td><td>26304</td></tr></tbody></table></div>

# %% [markdown]
# ### Triplets

# %% [markdown]
# <img border="0" alt="Triplets" src="https://spark.apache.org/docs/latest/img/triplet.png" width="400" height="50">

# %%
g.triplets.filter("edge.src = '31' AND edge.dst = '33'").rdd.count()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[59]: 36</div>

# %%
display(g.triplets.filter("edge.src = '31' AND edge.dst = '33'").limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>src</th><th>edge</th><th>dst</th></tr></thead><tbody><tr><td>List(31, San Antonio Shopping Center)</td><td>List(31, 33, 909889)</td><td>List(33, Rengstorff Avenue / California Street)</td></tr><tr><td>List(31, San Antonio Shopping Center)</td><td>List(31, 33, 904348)</td><td>List(33, Rengstorff Avenue / California Street)</td></tr><tr><td>List(31, San Antonio Shopping Center)</td><td>List(31, 33, 891372)</td><td>List(33, Rengstorff Avenue / California Street)</td></tr><tr><td>List(31, San Antonio Shopping Center)</td><td>List(31, 33, 872016)</td><td>List(33, Rengstorff Avenue / California Street)</td></tr><tr><td>List(31, San Antonio Shopping Center)</td><td>List(31, 33, 868145)</td><td>List(33, Rengstorff Avenue / California Street)</td></tr></tbody></table></div>

# %% [markdown]
# ### PageRank

# %% [markdown]
# <img border="0" alt="PageRank" src="https://upload.wikimedia.org/wikipedia/en/thumb/8/8b/PageRanks-Example.jpg/1024px-PageRanks-Example.jpg" width="400" height="300">

# %%
results = g.pageRank(resetProbability=0.15, maxIter=10)

display(results.vertices.orderBy(results.vertices.pagerank.desc()).limit(5))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>id</th><th>desc_terminal</th><th>pagerank</th></tr></thead><tbody><tr><td>2</td><td>San Jose Diridon Caltrain Station</td><td>3.953111146508694</td></tr><tr><td>70</td><td>San Francisco Caltrain (Townsend at 4th)</td><td>3.356879832961734</td></tr><tr><td>28</td><td>Mountain View Caltrain Station</td><td>2.453326956741646</td></tr><tr><td>22</td><td>Redwood City Caltrain Station</td><td>2.2698152011252226</td></tr><tr><td>69</td><td>San Francisco Caltrain 2 (330 Townsend)</td><td>2.2291427994840958</td></tr></tbody></table></div>
